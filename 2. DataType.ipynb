# %%
# Numbers

student_roll_number = 55       #int - intiger
student_percentage = 70.45     #float - floating 
comp = 10+5j                   # complex


# String

student_Name = "Mohit"          #str
print(student_Name)


student_surname = 'demo'        #str

student_info = '''student name is 
                demo studet age is 20'''


# boolean

isStudent_Present = True     # 1
isEligible = False           # 0


# nothing

user_name = None   # null
# Out:
# Mohit

# %% [markdown]
# ### Non-Premitive

# %%
students = ["mohit","rohit","deep"]
students.append("demoUser")

print(students)
# Out:
# ['mohit', 'rohit', 'deep', 'demoUser']

# %%
students = ["mohit","rohit","deep"]
print(students)
print(id(students))



students.append("demoUser")
print(students)
print(id(students))
# Out:
# ['mohit', 'rohit', 'deep']
# 3217282585984
# ['mohit', 'rohit', 'deep', 'demoUser']
# 3217282585984

# %%
roll_number = 55
print(roll_number) 
print(id(roll_number))


roll_number = 66
print(roll_number) 
print(id(roll_number))
# Out:
# 55
# 140736164367160
# 66
# 140736164367512

# %% [markdown]
# ### Explicite Type Conversion

# %%
percentage = 80.70
print(type(percentage))

temp = int(percentage)
print(temp)
# Out:
# <class 'float'>
# 80

# %% [markdown]
# #### Implicit Type Conversion

# %%
num1 = 10         # int
num2 = 10.15      # float


res = num1 + num2

print(res)
print(type(res))
# Out:
# 20.15
# <class 'float'>

# %%
num1 = 10
num2 = 20

# temp1 = int(num1)   # 10
# temp2 = float(num2)   # 20.0

# res = temp1 + temp2


print(res)


# user_name = "demo"
# user_surname = "xyz"

# full_name = user_name + user_surname

# print(full_name)
# Out:
# 30.0

# %%
num1 = "10"
num2 = "20.10"

print(num1 + num2)

temp1 = int(num1)   # 10
temp2 = float(num2)   # 20.0
temp3 = int(temp2)

res = temp1 + temp3

print(res)
# Out:
# 1020.10
# 30
