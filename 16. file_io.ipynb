# %%
str1 = " hello user "
str2 = " hello user 2 "

fobj = open("temp1.txt","w")
fobj.write(str1)

fobj.close()

# %%
str1 = " hello user "
str2 = " hello user 2 "

fobj = open("temp.txt","a")
fobj.write(str1)

fobj.close()

# %%
fobj = open("temp.txt","r")
content = fobj.read()
print(content)

fobj.close()
# Out:
# hello user 2hello user 2hello user hello user  hello user  hello user  hello user

# %%
fobj = open("temp3.txt","x")
fobj.close()

# %%
str1 = "temp data"

fobj = open("temp4.txt","w")
fobj.write(str1)

fobj.close()

# %%
listOne = ["userone\n","usertwo\n","user3\n"]

str1 = "demoOne\n"
str2 = "demoTwo\n"

str3 = str1 + str2
# print(str3)

fobj = open("temp5.txt","w")
fobj.writelines(str3)

fobj.close()

# %%
fobj = open("temp5.txt","r")

# info = fobj.read()
# info = fobj.readline()
info = fobj.readlines()

print(info)


fobj.close()
# Out:
# ['demoOne\n', 'demoTwo\n']

# %%
# with keyword

with open("temp5.txt","r") as fobj:
    info = fobj.read()
    print(info)
# Out:
# demoOne
# demoTwo

# %%
with open("temp6.txt","w") as demo:
    demo.write("this is demo code")
