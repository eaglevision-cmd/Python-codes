# %%
class car:

    def greet():
        print("hello")



obj1 = car
obj1.greet()
# Out:
# hello

# %%
def greet():
    print("hello")

greet()
# Out:
# hello

# %%
class car:

    def greet():          #method
        print("hello")



obj1 = car
obj1.greet()

# %%
class Car:

    def __init__(self,name,color,price,milage):
        # self.name = "demo"
        # self.color = "red"
        # self.price = "8l"
        # self.milage = 20

        self.name = name
        self.color = color
        self.price = price
        self.milage = milage


    def display_info(self):
        print(self.name)
        print(self.color)
        print(self.price)
        print(self.milage)


obj1 = Car("nexon","white","10l",25)
obj1.display_info()

obj2 = Car("punch","red","8l",20)
obj2.display_info()

car_name = input("enter car name")
car_color = input("enter car color")
car_price = input("enter car price")
car_milage = input("enter car milage")

obj3 = Car(car_name, car_color, car_price, car_milage)
obj3.display_info()
# Out:
# nexon
# white
# 10l
# 25
# punch
# red
# 8l
# 20
# demo
# black
# 15l
# 18

# %%
user_name=input("enter your name")

print("your name is :",user_name)

# %%
class StudentData:  # pascalcase
    
    def display_information():
        pass

# %%
student_name = "demoUser"
print(student_name)

# %%
ACC_NUM = 525252550

# %%
_acc_balanace = 50000

# %%
listOne = [1,2,3,7]
listTwo = [4,5,6,8]

# 1 ,2 ,3 , 4, 5

res = listOne + listTwo
# print(res)

if len(res)%2==0:
    indexnum = int(len(res)/2)
    # print(indexnum)

    num1 = res[indexnum]
    num2 = res[indexnum-1]

    addition = num1 + num2

    half = addition /2
    print(half)

else:
    indexnum = int(len(res)/2)
    # print(indexnum)
    print(res[indexnum])
# Out:
# 5.5

# %%
num_one = 10
num_two = 20

#     10 + 20
print(num_one + num_two)

num_one = 10
num_two = 40

print(num_one + num_two)
# Out:
# 30
# 70

# %%
def Add(num1 , num2): # placeholder
    print(num1 + num2)

Add(10,20)
Add(20,20)
Add(30,20)
Add(40,20)
# Out:
# 30
# 40
# 50
# 60

# %%
class calculator:
    def __init__(self,num_one,num_two):
        self.num_one = num_one
        self.num_two = num_two

    def Add(self): # placeholder
        print(self.num_one + self.num_two)
        

    def Sub(self):
        print(self.num_one - self.num_two)



obj1 = calculator(10,20)
obj1.Add()
obj1.Sub()

# obj2 = calculator(20,20)
# obj2.Add()
# Out:
# 30
# -10

# %%
listOne = [10,20,30]
print(type(listOne))

listOne.append(40)
# Out:
# <class 'list'>

# %%
# def __init__()   ->  special method  / constructor
# def add()        ->  normal method

# %%
class Demo:
    def __init__(self):
        print("this is special method")

    def temp(self):
        print("this is normal method")

obj1 = Demo()
obj1.temp()
# Out:
# this is special method
# this is normal method

# %%
class BankAtm:

    def __init__(self):
        self.pin = " "

    def Menu(self):
        print("1. Enter 1 to Set Pin")
        print("2. Enter 2 to Check Balance")
        print("3. Enter 3 to Deposite Money")
        print("4. Enter 4 to Withdraw Money")
        print("5. Enter 5 to Change Pin")
        print("6. Enter 6 to Exit")

        choice = int(input("enter Your Choice"))

        match choice:

            case 1:
                self.set_pin()

            case 2:
                pass

            case 3:
                pass

            case 4:
                pass

            case 5:
                pass

            case 6:
                pass

    def set_pin(self):
        if self.pin==" ":
            input_pin = input("enter pin")
            self.pin = input_pin
            print("pin set",self.pin)

        else:
            print("pin is already set")

obj1 = BankAtm()
obj1.Menu()
# Out:
# 1. Enter 1 to Set Pin
# 2. Enter 2 to Check Balance
# 3. Enter 3 to Deposite Money
# 4. Enter 4 to Withdraw Money
# 5. Enter 5 to Change Pin
# 6. Enter 6 to Exit
# pin set 12345

# %%
num1 = 10

print(10+num1)
# Out:
# 30
