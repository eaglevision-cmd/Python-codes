# %%
tupleOne = ("user1","user2","user3")

print(tupleOne)

# tupleOne.append("user4")

# print(tupleOne)

print(tupleOne[2])
# Out:
# ('user1', 'user2', 'user3')
# user3

# %%
tupleOne = ("user1","user2","user3")

# [start : end : step]

# print(tupleOne[0:2])
# print(tupleOne[0:])
# print(tupleOne[:3])
# print(tupleOne[:])

# print(tupleOne[ : :3])
# print(tupleOne[::-1])
# print(tupleOne[::-3])
# Out:
# ('user3',)

# %%
tupleOne = ("user1","user2","user3","user2","user3")
#              0  ,   1  

# print(tupleOne)
# for i , j in enumerate(tupleOne):
#     if i == 1:
#         continue

#     print(j)
# Out:
# ('user1', 'user2', 'user3', 'user2', 'user3')

# %%
tupleOne = ("user1","user2",10 , 30 ,True)            # hetro
tupleOne = ("user1","user2","user3","user2","user3")  #  homo

print(tupleOne)

# tup1 = [True , True , True]
# Out:
# ('user1', 'user2', 10, 30, True)

# %%
tupleOne = ("user1","user2",("user3","user2","user3"))

# print(tupleOne)

print(len(tupleOne))
# Out:
# 3

# %%
tupleOne = ("user1","user2","user3","user2","user3")  
#             0     ,  1   ,  2    ,   3    ,   4     # positive
#    ------------------------------------->

#            -5    , -4     ,  -3  ,   -2  ,     -1     # negative
#     <----------------------------------------

print(tupleOne[2])
print(tupleOne[-3])
# Out:
# user3
# user3

# %%
tupleOne = ("user1","user2")
tupleTwo = ("user3","user4")

res = tupleOne + tupleTwo

print(res)

print(tupleTwo + tupleOne)
# Out:
# ('user1', 'user2', 'user3', 'user4')
# ('user3', 'user4', 'user1', 'user2')

# %%
tupleOne = ("user1","user2","user3","user2","user3") 

# print(tupleOne.count("user1"))

# print(tupleOne.index("user2"))
# Out:
# 1

# %%
# tupleOne = ("user1","user2","user3","user2","user3")

tupleOne = ("demo","user")

# print(len(tupleOne))

print(min(tupleOne))

# demo     user    // ascii   
# e        e

# print("d :",ord("d") , "u :", ord("u"))
# Out:
# demo

# %%
temp = 0

tup1 = (1,6,7,2,9,5)

# for i in tup1:
#     temp += i

print(temp)
# print(sum(tup1))

print(sorted(tup1))
# Out:
# 0
# [1, 2, 5, 6, 7, 9]

# %%
# set1 = (1,6,7,2,9,5)

# print(set1)
# print(set1[0])

# str1 = str(set1)  #  "(1,6,7,2,9,5)"    #"[Demouser"

# print(str1)
# print(str1[0])

# print(type(tup1))

# templist = list(tup1)

# print(templist)

# set1 = set(set1)

# print(set1)

# "(1, 6, 7, 2, 9, 5)"
# Out:
# (1, 6, 7, 2, 9, 5)
# 1
# (1, 6, 7, 2, 9, 5)
# (

# %%
tupleOne = ("user1","user2","user3","user2","user3") 

for i in enumerate(tupleOne):
    print(i )
# Out:
# (0, 'user1')
# (1, 'user2')
# (2, 'user3')
# (3, 'user2')
# (4, 'user3')

# %%
# tupleOne = ("user1","user2","user3")
tupleOne = (1,2,3,4)

temp = list(reversed(tupleOne))

print(temp)
# print(" ".join(reversed(tupleOne)))
# Out:
# [4, 3, 2, 1]

# %%
tupleOne = (1,"True")

# print(any(tupleOne))

print(all(tupleOne))
# Out:
# True

# %%
setOne = { "one" , "Two" , "Three"}

print(setOne)

setOne.add("Four")

print(setOne)
# Out:
# {'Two', 'Three', 'one'}
# {'Two', 'Three', 'one', 'Four'}

# %%
setOne = { "one" , "Two" , "Three" , "one" ,1 , False}
# print(setOne)
for i in setOne:
    print(i)
# Out:
# False
# Three
# 1
# one
# Two

# %%
setOne = { "one" , "Two" ,("four","five"), "Three"}

print(setOne)
# Out:
# {'Two', 'one', ('four', 'five'), 'Three'}

# %%
setOne = { "one" , "Two" }
print(setOne)

# setOne.add("Three")
# setOne.update({"four","five"})

temp = {"four","five"}

setOne.update(temp)

print(setOne)
# Out:
# {'Two', 'one'}
# {'Two', 'five', 'one', 'four'}

# %%
setOne = { "one" , "Two" , "Three"}
print(setOne)


# setOne.remove("five")
# setOne.discard("five")
# setOne.pop()
# setOne.clear()

# temp = setOne.copy()
# print(temp)


# temp2 = setOne
# print(temp2)
# Out:
# {'Two', 'Three', 'one'}
# {'Two', 'Three', 'one'}
# {'Two', 'Three', 'one'}

# %%
set1 = {"one","two","three"}
set2 = {"four","five","three"}

# print(set1.union(set2))  # combine
# print(set1.intersection(set2))   # common

# print(set2.difference(set1))
# Out:
# {'five', 'four'}

# %%
set1 = {"one","two","three"}
nums = {5,2,3}

# print(len(set1))
# print(max(set1))
# print(min(set1))
# print(sum(set1))
# print(sum(nums))

# print(sorted(set1))

# print(type(set1))

listOne = list(set1)
print(listOne)

tupone = tuple(set1)
print(tupone)

str1 = str(set1)
print(str1)
# Out:
# ['one', 'two', 'three']
# ('one', 'two', 'three')
# {'one', 'two', 'three'}

# %%
set1 = {"one","two","three"}

for i , j in enumerate(set1):
    print(i , j)
# Out:
# 0 one
# 1 two
# 2 three

# %%
set1 = {"one","two","three",0}

print(all(set1))
# Out:
# False

# %%
Set2 = {5,9,7,6,1,8,3}

print(Set2)
# Out:
# {1, 3, 5, 6, 7, 8, 9}
