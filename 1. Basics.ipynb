# %%
# int num = 10
# let num = 10

num1 = 10
num2 = 20

num1 = 30
num2 = 50

# student_name = True
# _student_age = 20



# True = "mohit"

print(num1 + num2)

print(student_name)


# demo 
# random



# 1num = 10


# True = 10;




var1 = " True  or "
var2 = True

print(type(var1))
print(type(var2))
print(var1)


user_name = "Rohit"


student_name = "dipak"
# Out:
# 80
# mohit
# <class 'str'>
# <class 'bool'>
#  True  or

# %% [markdown]
# ### Variables

# %%
student_name = "Mohit"  # this variable is for student name
print(student_name)     # This is use to print student name 



print("hello")  #  this is use for print hello

""" this is demo Code
this is only for understanding comments 
print(student_name)
"""
# Out:
# Mohit
# hello
# ' this is demo Code\nthis is only for understanding comments \nprint(student_name)\n'

# %% [markdown]
# ### Indentation

# %%
def demo():
    print("hello")
    # ghj
    #fghjk
    #fghj


def demo():
    #ghjk
    #fghjk
    #fghj
