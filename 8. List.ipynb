# %%
students = ["user1","user2","user3","user4"]
#             0    ,  1     , 2    , 3

# print(students)
# print(id(students))

# students.append("user4")

# print(students)
# print(id(students))


# print(students[2])
# Out:
# user3

# %%
students = ["user1","user2","user3","user4"]
#             0    ,  1     , 2    , 3

#    [Start : end : steps]
print(students[0:3])
print(students[:3])
print(students[0:])
print(students[:])
print(students[::2])

print(students[::3])
# Out:
# ['user1', 'user2', 'user3']
# ['user1', 'user2', 'user3']
# ['user1', 'user2', 'user3', 'user4']
# ['user1', 'user2', 'user3', 'user4']
# ['user1', 'user3']
# ['user1', 'user4']

# %%
students = ["user1","user2","user3","user4","user1","user1"]
#             0    ,  1     , 2    , 3

# for i in students:
#     print(i, end=" ")

print(students)

# set1 = set(students)

# print(set1)


students.append("user5")

print(students)
# Out:
# ['user1', 'user2', 'user3', 'user4', 'user1', 'user1']
# ['user1', 'user2', 'user3', 'user4', 'user1', 'user1', 'user5']

# %%
listOne = ["user1",55,True]   # hetrogeneas
listtwo = [1,2,3,4,5,6]       #homogeneas


print(listOne)
print(listtwo)
# Out:
# ['user1', 55, True]
# [1, 2, 3, 4, 5, 6]

# %%
listOne = [1 ,2 ,3 ,[4,5,6,[1,2,3]] ,7,8,9]

print(listOne)

print(listOne[3][3][2])

# for i in listOne:
#     if i == 3:
#         for j in range(2):
#             print(i[j])
#     else:
#         print(i)
# Out:
# [1, 2, 3, [4, 5, 6, [1, 2, 3]], 7, 8, 9]
# 3

# %%
students = ["user1","user2","user3","user4","user1","user1"]
# positive=  0      , 1    ,  2    ,    3  ,    4  ,  5
#   ----------------------------->

# negative=                   -4   ,   -3   ,  -2    ,    -1
#         <------------------------------------

print(students[-3])
print(students[3])
# Out:
# user4
# user4

# %%
listone = ["user1","user2"]
listtwo = ["user3","user4"]
listthree = ["user5","user6"]

res = listtwo + listone

print(res)

print(listone + listtwo + listthree)
# Out:
# ['user3', 'user4', 'user1', 'user2']
# ['user1', 'user2', 'user3', 'user4', 'user5', 'user6']

# %%
listone = ["user1","user2","user3","user3"]

print(listone)

# listone.append("user3")
# temp = ["user3","user4"]
# listone.extend(temp)
# listone.insert(0,"user4")

# listone.remove("user3")
# listone.pop(0)

# listone.clear()

# print(listone.index("user3"))

# print(listone.count("user3"))


# print(listone)
# Out:
# ['user1', 'user2', 'user3', 'user3']
# 2

# %%
# nums = [8,6,7,9,3,4,5,1]
nums = [1,2,3,4]


print(nums)

# nums.sort()
nums.reverse()

print(nums)
# Out:
# [1, 2, 3, 4]
# [4, 3, 2, 1]

# %%
listone = ["user1","user2"]
print("original :",listone)
print(id(listone))
print("--------------------")

copyone = listone.copy()   # shallow copy
print("copy1 :",copyone)
print(id(copyone))

print("--------------------")

copytwo = listone         # deep copy / Allising
print("copy2",copytwo)
print(id(copytwo))
copytwo.append("user3")


print("original :",listone)
print("copy1 :",copyone)
print("copy2",copytwo)
# Out:
# original : ['user1', 'user2']
# 2332677164096
# --------------------
# copy1 : ['user1', 'user2']
# 2332660334528
# --------------------
# copy2 ['user1', 'user2']
# 2332677164096
# original : ['user1', 'user2', 'user3']
# copy1 : ['user1', 'user2']
# copy2 ['user1', 'user2', 'user3']

# %%
# listone = ["user1","user2"]
listone = ["demo","user"]
nums = [8,6,9,4,2]

# print(len(listone))
# print(max(nums))

# print(ord("d"),ord("u"))

# print(max(listone))

# print(min(nums))
# print(min(listone))
# Out:
# 2
# demo

# %%
listone = ["demo","user"]
nums = [8,6,9,4,2]


# print(sum(nums))

# print(sum(listone))

# print(sorted(nums))
# print(type(nums))
# Out:
# 29
# <class 'list'>

# %%
nums = [8,6,9,4,2]

print(nums)

str1 = str(nums)

print(str1)  # "[8, 6, 9, 4, 2]"
# Out:
# [8, 6, 9, 4, 2]
# [8, 6, 9, 4, 2]

# %%
students = ["user1","user2","user3","user4"]

# for i ,j in enumerate(students):
#     print(i,j)


print(" ".join(reversed(students)))
# Out:
# user4 user3 user2 user1

# %%
students = [True,True,1]

# print(any(students))

print(all(students))
# Out:
# True

# %%
#   *
#  * *
# * * *

# %%
col = 3
row = 1
# space = " "
spacecount = 2

for i in range(col):
    for j in range(row):
        print(" " * spacecount, "*", end="")
        spacecount -=1
    print(" ")
    row +=1
# Out:
#    *
#   * *
#  * * *

# %%
col = 5
# row = 1
# space = " "
spacecount = 4
starcount = 1

for i in range(col):
        print(" " * spacecount, "*" * starcount, end="")
        spacecount -=1
        starcount += 2
        print(" ")
    # row +=1
# Out:
#      *
#     ***
#    *****
#   *******
#  *********
