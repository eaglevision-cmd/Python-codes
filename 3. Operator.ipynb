# %%
print(10 + 20)
# Out:
# 30

# %% [markdown]
# ### Assignment Operators

# %%
# =  Assignment op
# right side value assign to left side 

user_name = "Mohit"
print(user_name)

#add and Assign

num1 = 10
# num1 = num1 + 5
# num1 += 5

print(num1)


# Subtract and Assign

# num1 = num1 - 5
num1 -=5

print(num1)
# Out:
# Mohit
# 10
# 5

# %%
num = 5
num2 = 2

res = num + num2

# num1 -=5
res *= 3

print(res)

# %%
num1 = 10
num2 = 3

res = num1 // num2

print(res)
# Out:
# 3

# %%
num1 = 10
num2 = 3

res = num1 %  num2

print(res)
# Out:
# 1

# %%
num1 = 2
num2 = 3

res = num1 ** num2

print(res)
# Out:
# 8

# %% [markdown]
# ### Comparison Operators

# %%
# Equal To

num1 = 10
num2 = 20

print(num1 == num2)

print(num1 != num2)


num3 = 20
num4 = 40

print( num3 > num4 )

print(num3 < num4)
# Out:
# False
# True
# False
# True

# %%
num1 = 15
num2 = 10

print(num1 <= num2)
# Out:
# False

# %% [markdown]
# ### Logical Operators

# %%
user_Age = 19
nationality = "indian"

# and --> both condition true

# or --> any one condition is true
#    10     >= 10

if user_Age >= 18 or nationality == "india":

    print("eligible for voating")
else:
    print("not eligible for voating")
# Out:
# eligible for voating

# %%
age = 28

if not age >=18:
    print("eligible for voating")
else:
    print("not eligible for voating")
# Out:
# not eligible for voating

# %% [markdown]
# ### Identity Operators

# %%
num1 = 10
num2 = 20

print(id(num1))
print(id(num2))

print(num1 is not num2)
# Out:
# 140736164365720
# 140736164366040
# True

# %% [markdown]
# ### Membership Operators

# %%
student_name = "Demo User"

print("z" not in student_name)
# Out:
# True
