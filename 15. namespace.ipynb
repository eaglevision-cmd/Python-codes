# %%
name = "mohit"   # global namespace
age = 22         # global namespace


def temp():
    roll = 55
    mark = 75

    print(name)
    print(age)
    print(roll)
    print(mark)

temp()

print(name)
print(age)
print(roll)
print(mark)
# Out:
# mohit
# 22
# 55
# 75
# mohit
# 22
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 18
#      14 temp()
#      15
#      16 print(name)
#      17 print(age)
# ---> 18 print(roll)
#      19 print(mark)
#
# NameError: name 'roll' is not defined

# %%
def temp():
    username = "mohit"   # local Namespace
    age = 22             #local namespace
    print(username)
    print(age)

# print(username)
# print(age)
temp()
# Out:
# mohit
# 22

# %%
student_name = "demoUser"    # global

def one():
    student_age = 22         # enclosing
    print(student_roll)

    def two():
        student_roll = 55    # local
        print(student_roll)
        print(student_age)
        print(student_name)

    two()
one()
# Out:
# 55
# 22
# demoUser

# %%
name = "demouser"

length = len(name)

print(length)
# Out:
# 8

# %%
name = "mohit"

def temp():
    name = "demo"    #shadowing
    print(name)

temp()

print(name)
# Out:
# demo
# mohit

# %%
name = "mohit"

def temp():
    global name
    name = "demo"    
    print(name)

temp()

print(name)
# Out:
# demo
# demo

# %%
name = "demo"

def one():
    name = "demo1"

    def two():
        name = "demo2"
        print("local scope",name)

    two()
    print("enclosing",name)

one()
print("global",name)

print("built in",len(name))
# Out:
# local scope demo2
# enclosing demo1
# global demo
# built in 4

# %%
str1 = "harshalharshal"
dict1 = {}

set1 = set(str1)


for i in set1:
    dict1[i]=str1.count(i)

print(dict1)
# Out:
# {'r': 2, 'h': 4, 'a': 4, 'l': 2, 's': 2}
